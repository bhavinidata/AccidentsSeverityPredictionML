# %%
dbutils.library.installPyPI("scikit-learn")
dbutils.library.installPyPI("joblib")
dbutils.library.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Import necessary libraries
from pyspark.sql import SparkSession
from pyspark import SparkFiles
from pyspark.sql import DataFrame
import pyspark.sql.functions as F
from pyspark.sql import SQLContext
import pandas as pd
import numpy as np
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import pickle
import joblib
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# get or create Spark session
app_name = "intro-to-pyspark"
spark = SparkSession.builder.appName(app_name).getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# #NOTE - We need for final demo
# # Read raw csv file and get it in spark dataframe.
# url = "/FileStore/tables/US_Accidents_May19.csv"

# df = spark.read \
#     .format("com.databricks.spark.csv") \
#     .options(header='true', inferSchema = True) \
#     .load(url)
# df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # Keep only necessary columns to store in AWS postgress
# df_to_load = df.select("Severity", "TMC", "Start_Lat", "Start_Lng", "Distance(mi)", "Start_Time","End_Time", "Description", "Street", "City", "State" \
#                        ,"Zipcode", "Country", "Timezone","Weather_Timestamp", "Temperature(F)", "Wind_Chill(F)", "Humidity(%)", "Pressure(in)" \
#                        ,"Visibility(mi)", "Wind_Speed(mph)", "Precipitation(in)", "Weather_Condition")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(df_to_load)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Get secret value from AWS postgres database
import boto3

secret_name = "ut/secret/postgre"
region_name = "us-east-2"
access_key = "AKIA4DI3HF5D4RU6LXGI"
secret_key = "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"

session = boto3.session.Session(aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=region_name)
client = session.client('secretsmanager')
secret_value = client.get_secret_value(SecretId=secret_name)
secret_value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: {&#39;ARN&#39;: &#39;arn:aws:secretsmanager:us-east-2:831670136647:secret:ut/secret/postgre-89t4Kr&#39;,
#  &#39;Name&#39;: &#39;ut/secret/postgre&#39;,
#  &#39;VersionId&#39;: &#39;6431e168-a66c-4698-b6a8-89ac65fe50cc&#39;,
#  &#39;SecretString&#39;: &#39;{&#34;username&#34;:&#34;postgres&#34;,&#34;password&#34;:&#34;changeme&#34;,&#34;engine&#34;:&#34;postgres&#34;,&#34;host&#34;:&#34;dataviz.c2s0ukcjjgxj.us-east-2.rds.amazonaws.com&#34;,&#34;port&#34;:5432,&#34;dbInstanceIdentifier&#34;:&#34;dataviz&#34;}&#39;,
#  &#39;VersionStages&#39;: [&#39;AWSCURRENT&#39;],
#  &#39;CreatedDate&#39;: datetime.datetime(2019, 12, 21, 16, 32, 49, 995000, tzinfo=tzlocal()),
#  &#39;ResponseMetadata&#39;: {&#39;RequestId&#39;: &#39;784071b5-ea20-4c3e-a316-f59e2ab39080&#39;,
#   &#39;HTTPStatusCode&#39;: 200,
#   &#39;HTTPHeaders&#39;: {&#39;date&#39;: &#39;Thu, 16 Jan 2020 15:37:33 GMT&#39;,
#    &#39;content-type&#39;: &#39;application/x-amz-json-1.1&#39;,
#    &#39;content-length&#39;: &#39;435&#39;,
#    &#39;connection&#39;: &#39;keep-alive&#39;,
#    &#39;x-amzn-requestid&#39;: &#39;784071b5-ea20-4c3e-a316-f59e2ab39080&#39;},
#   &#39;RetryAttempts&#39;: 0}}</div>

# %%
# Get Connection
import json
def get_connection(secret_value):
  return json.loads(secret_value['SecretString'])
get_connection(secret_value)
connection = get_connection(secret_value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Postgres credentials
jdbcHostname = connection['host']
jdbcPort = connection['port']
jdbcDatabase = "postgres"
dialect = "postgresql"
jdbcUsername = connection['username']
jdbcPassword = connection['password']

jdbcUrl = f"jdbc:{dialect}://{jdbcHostname}:{jdbcPort}/{jdbcDatabase}"
connectionProperties = {
  "user" : jdbcUsername,
  "password" : jdbcPassword,
  "driver" : "org.postgresql.Driver" 
}
# for mysql driver = com.mysql.jdbc.Driver
# jdbcUrl
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# #NOTE - Need to comment out for Demo
# # table "US_accidents_data" contains lat, lng data in case we need it later for heat map.
# # table = "US_accidents_row"
# table = "US_accidents_data"
# mode = "overwrite" # options are: error, append, overwrite

# df_to_load.write.jdbc(jdbcUrl, table, mode, connectionProperties)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # read from postgres
# df_fromPostgres = spark.read.jdbc(url = jdbcUrl, table = table, properties = connectionProperties)
# display(df_fromPostgres)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # write to csv file
# df_fromPostgres.write.format("com.databricks.spark.csv").mode("overwrite").option("header", "true").save("dbfs:/FileStore/df/spark_data.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # print schema
# df_fromPostgres.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# url = "/FileStore/df/spark.csv"
url = "/FileStore/df/spark_data.csv"

df_from_local = spark.read \
    .format("com.databricks.spark.csv") \
    .options(header='true', inferSchema = True) \
    .load(url)
df_from_local.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-----+------------------+------------------+------------+-------------------+-------------------+--------------------+--------------------+------------+-----+----------+-------+----------+-------------------+--------------+-------------+-----------+------------+--------------+---------------+-----------------+-----------------+
# Severity|  TMC|         Start_Lat|         Start_Lng|Distance(mi)|         Start_Time|           End_Time|         Description|              Street|        City|State|   Zipcode|Country|  Timezone|  Weather_Timestamp|Temperature(F)|Wind_Chill(F)|Humidity(%)|Pressure(in)|Visibility(mi)|Wind_Speed(mph)|Precipitation(in)|Weather_Condition|
# +--------+-----+------------------+------------------+------------+-------------------+-------------------+--------------------+--------------------+------------+-----+----------+-------+----------+-------------------+--------------+-------------+-----------+------------+--------------+---------------+-----------------+-----------------+
#        3|201.0|         39.865147|        -84.058723|        0.01|2016-02-08 05:46:00|2016-02-08 11:00:00|Right lane blocke...|              I-70 E|      Dayton|   OH|     45424|     US|US/Eastern|2016-02-08 05:58:00|          36.9|         null|       91.0|       29.68|          10.0|           null|             0.02|       Light Rain|
#        2|201.0|39.928059000000005|        -82.831184|        0.01|2016-02-08 06:07:59|2016-02-08 06:37:59|Accident on Brice...|            Brice Rd|Reynoldsburg|   OH|43068-3402|     US|US/Eastern|2016-02-08 05:51:00|          37.9|         null|      100.0|       29.65|          10.0|           null|              0.0|       Light Rain|
#        2|201.0|         39.063148|        -84.032608|        0.01|2016-02-08 06:49:27|2016-02-08 07:19:27|Accident on OH-32...|      State Route 32|Williamsburg|   OH|     45176|     US|US/Eastern|2016-02-08 06:56:00|          36.0|         33.3|      100.0|       29.67|          10.0|            3.5|             null|         Overcast|
#        3|201.0|         39.747753|-84.20558199999999|        0.01|2016-02-08 07:23:34|2016-02-08 07:53:34|Accident on I-75 ...|              I-75 S|      Dayton|   OH|     45417|     US|US/Eastern|2016-02-08 07:38:00|          35.1|         31.0|       96.0|       29.64|           9.0|            4.6|             null|    Mostly Cloudy|
#        2|201.0|         39.627781|        -84.188354|        0.01|2016-02-08 07:39:07|2016-02-08 08:09:07|Accident on McEwe...|Miamisburg Center...|      Dayton|   OH|     45459|     US|US/Eastern|2016-02-08 07:53:00|          36.0|         33.3|       89.0|       29.65|           6.0|            3.5|             null|    Mostly Cloudy|
#        2|201.0|         39.745888|         -84.17041|        0.01|2016-02-08 08:43:20|2016-02-08 09:13:20|Accident on Wayne...|         Glencoe Ave|      Dayton|   OH|45410-1721|     US|US/Eastern|2016-02-08 08:28:00|          33.8|         null|      100.0|       29.63|           3.0|            2.3|             null|         Overcast|
#        2|201.0|         39.748329|        -84.224007|        0.01|2016-02-08 08:53:17|2016-02-08 09:23:17|Accident on James...|S James H McGee Blvd|      Dayton|   OH|     45402|     US|US/Eastern|2016-02-08 08:58:00|          35.6|         null|       99.0|       29.65|           7.0|            2.3|             null|    Mostly Cloudy|
#        2|201.0|         39.752174|        -84.239952|         0.0|2016-02-08 09:24:37|2016-02-08 09:54:37|Accident on Delph...|         Delphos Ave|      Dayton|   OH|45417-1727|     US|US/Eastern|2016-02-08 08:56:00|          36.0|         31.1|       89.0|       29.65|          10.0|            5.8|             null|    Mostly Cloudy|
#        2|201.0|         25.928591|-80.18824000000001|         0.0|2018-10-18 08:33:41|2018-10-18 09:03:27|Accident on FL-82...|         NE 167th St|       Miami|   FL|     33162|     US|US/Eastern|2018-10-18 08:31:00|          82.9|         null|       82.0|       30.14|          10.0|            6.9|             null| Scattered Clouds|
#        2|222.0|         25.883673|        -80.262787|         0.0|2018-10-18 08:36:39|2018-10-18 09:06:14|Queueing traffic ...|     Gratigny Expy E|   Opa Locka|   FL|     33054|     US|US/Eastern|2018-10-18 08:5

# %%
df_from_local.groupBy("Severity").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-------+
# Severity|  count|
# +--------+-------+
#        1|    814|
#        3| 715582|
#        4|  72002|
#        2|1455524|
#        0|     17|
# +--------+-------+
#
# </div>

# %%
# #Keep only severity 2, 3 and 4. 
df_Severity = df_from_local.where((df_from_local["Severity"]==2) | (df_from_local["Severity"]==3) | (df_from_local["Severity"]==4))
display(df_Severity)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Severity</th><th>TMC</th><th>Start_Lat</th><th>Start_Lng</th><th>Distance(mi)</th><th>Start_Time</th><th>End_Time</th><th>Description</th><th>Street</th><th>City</th><th>State</th><th>Zipcode</th><th>Country</th><th>Timezone</th><th>Weather_Timestamp</th><th>Temperature(F)</th><th>Wind_Chill(F)</th><th>Humidity(%)</th><th>Pressure(in)</th><th>Visibility(mi)</th><th>Wind_Speed(mph)</th><th>Precipitation(in)</th><th>Weather_Condition</th></tr></thead><tbody><tr><td>3</td><td>201.0</td><td>39.865147</td><td>-84.058723</td><td>0.01</td><td>2016-02-08T05:46:00.000+0000</td><td>2016-02-08T11:00:00.000+0000</td><td>Right lane blocked due to accident on I-70 Eastbound at Exit 41 OH-235 State Route 4.</td><td>I-70 E</td><td>Dayton</td><td>OH</td><td>45424</td><td>US</td><td>US/Eastern</td><td>2016-02-08T05:58:00.000+0000</td><td>36.9</td><td>null</td><td>91.0</td><td>29.68</td><td>10.0</td><td>null</td><td>0.02</td><td>Light Rain</td></tr><tr><td>2</td><td>201.0</td><td>39.928059000000005</td><td>-82.831184</td><td>0.01</td><td>2016-02-08T06:07:59.000+0000</td><td>2016-02-08T06:37:59.000+0000</td><td>Accident on Brice Rd at Tussing Rd. Expect delays.</td><td>Brice Rd</td><td>Reynoldsburg</td><
'Heavy Rain' : 'Rain',
'Light Drizzle' : 'Clear',
'Light Thunderstorms and Rain' : 'Clear',
'Thunderstorm' : 'Rain',
'Snow' : 'Slippery',
'Smoke' : 'Low Visibility',
'Heavy Thunderstorms and Rain' : 'Rain',
'Thunderstorms and Rain' : 'Rain',
'Light Freezing Rain' : 'Slippery',
'Mist' : 'Low Visibility',
'Patches of Fog' : 'Low Visibility',
'Drizzle' : 'Clear',
'Heavy Snow' : 'Slippery',
'Light Freezing Fog' : 'Low Visibility',
'Shallow Fog' : 'Low Visibility',
'Light Freezing Drizzle': 'Clear',
'Blowing Snow' : 'Low Visibility',
'Light Ice Pellets' : 'Clear',
'Heavy Drizzle' : 'Rain',
'Light Rain Showers' : 'Clear',
'Rain Showers' : 'Rain',
'Ice Pellets' : 'Low Visibility',
'Squalls' : 'Low Visibility',
'Small Hail' : 'Low Visibility',
'Light Snow Showers' : 'Low Visibility',
'Volcanic Ash' : 'Low Visibility',
'Light Thunderstorms and Snow' : 'Clear',
'Sand' : 'Low Visibility',
'Funnel Cloud' : 'Low Visibility',
'Light Haze' : 'Clear',
'Heavy Thunderstorms with Small Hail' : 'Low Visibility',
'Heavy Rain Showers' : 'Rain',
'Heavy Thunderstorms and Snow' : 'Slippery',
'Low Drifting Snow' : 'Low Visibility',
'Snow Grains' : 'Slippery',
'Light Fog' : 'Clear',
'Heavy Blowing Snow' : 'Low Visibility',
'Heavy Ice Pellets' : 'Slippery',
'Light Hail' : 'Clear',
'Light Snow Grains' : 'Clear',
'Light Thunderstorm' : 'Clear',
'Light Blowing Snow' : 'Clear',
'Thunderstorms and Snow' : 'Rain',
'Hail' : 'Low Visibility',
'Heavy Freezing Rain' : 'Rain',
'Heavy Freezing Drizzle' : 'Rain',
'Snow Showers' : 'Rain',
'Blowing Sand' : 'Low Visibility',
'Dust Whirls' : 'Low Visibility',
'Heavy Smoke' : 'Low Visibility',
'Widespread Dust' : 'Low Visibility'
}


@udf(returnType=StringType())
def udf_weather_ctg(condition):
    if condition is not None:
        category = weather_dict.get(condition)
    else:
        category = "UNKNOWN"
    return category
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Replace multiple weather condition to main categories
df_weather_catg = df_Severity.withColumn("Weather_Category", udf_weather_ctg("Weather_Condition"))
display(df_weather_catg)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Severity</th><th>TMC</th><th>Start_Lat</th><th>Start_Lng</th><th>Distance(mi)</th><th>Start_Time</th><th>End_Time</th><th>Description</th><th>Street</th><th>City</th><th>State</th><th>Zipcode</th><th>Country</th><th>Timezone</th><th>Weather_Timestamp</th><th>Temperature(F)</th><th>Wind_Chill(F)</th><th>Humidity(%)</th><th>Pressure(in)</th><th>Visibility(mi)</th><th>Wind_Speed(mph)</th><th>Precipitation(in)</th><th>Weather_Condition</th><th>Weather_Category</th></tr></thead><tbody><tr><td>3</td><td>201.0</td><td>39.865147</td><td>-84.058723</td><td>0.01</td><td>2016-02-08T05:46:00.000+0000</td><td>2016-02-08T11:00:00.000+0000</td><td>Right lane blocked due to accident on I-70 Eastbound at Exit 41 OH-235 State Route 4
show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+-------+
# Weather_Category|  count|
# +----------------+-------+
#           Cloudy| 900633|
#   Low Visibility|  48624|
#            Clear|1171402|
#         Slippery|   7256|
#          UNKNOWN|  71976|
#             Rain|  43217|
# +----------------+-------+
#
# </div>

# %%
df_with_lat = df_weather_catg.fillna(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Store csv file with lat lng columns
df_with_lat.repartition(1).write.format("com.databricks.spark.csv").mode("overwrite").option("header", "true").save("dbfs:/FileStore/df/data_with_lat.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_weather_catg.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 2243108</div>

# %%
df_with_lat_noNull = df_weather_catg.select("Severity"  \
                          ,"Start_Lat","Start_Lng", "Start_Time", "Temperature(F)", "Visibility(mi)" \
                          , "Wind_Speed(mph)", "Weather_Category", "Pressure(in)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_with_lat_noNull = df_with_lat_noNull.dropna(how="any")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_with_lat_noNull.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 1785064</div>

# %%
# Store csv file with lat lng columns and droping na
df_with_lat_noNull.repartition(1).write.format("com.databricks.spark.csv").mode("overwrite").option("header", "true").save("dbfs:/FileStore/df/df_with_lat_noNull.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pd_lat = df_with_lat.toPandas()
df_pd_lat.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Severity</th>
#       <th>TMC</th>
#       <th>Start_Lat</th>
#       <th>Start_Lng</th>
#       <th>Distance(mi)</th>
#       <th>Start_Time</th>
#       <th>End_Time</th>
#       <th>Description</th>
#       <th>Street</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Zipcode</th>
#       <th>Country</th>
#       <th>Timezone</th>
#       <th>Weather_Timestamp</th>
#       <th>Temperature(F)</th>
#       <th>Wind_Chill(F)</th>
#       <th>Humidity(%)</th>
#       <th>Pressure(in)</th>
#       <th>Visibility(mi)</th>
#       <th>Wind_Speed(mph)</th>
#       <th>Precipitation(in)</th>
#       <th>Weather_Condition</th>
#       <th>Weather_Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>201.0</td>
#       <td>39.865147</td>
#       <td>-84.058723</td>
#       <td>0.01</td>
#       <td>2016-02-08 05:46:00</td>
#       <td>2016-02-08 11:00:00</td>
#       <td>Right lane blocked due to accident on I-70 Eas...</td>
#       <td>I-70 E</td>
#       <td>Dayton</td>
#       <td>OH</td>
#       <td>45424</td>
#       <td>US</td>
#       <td>US/Eastern</td>
#       <td>2016-02-08 05:58:00</td>
#       <td>36.9</td>
#       <td>0.0</td>
#       <td>91.0</td>
#       <td>29.68</td>
#       <td>10.0</td>
#       <td>0.0</td>
#       <td>0.02</td>
#       <td>Light Rain</td>
#       <td>Clear</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>201.0</td>
#       <td>39.928059</td>
#       <td>-82.831184</td>
#       <td>0.01</td>
#       <td>2016-02-08 06:07:59</td>
#       <td>2016-02-08 06:37:59</td>
#       <td>Accident on Brice Rd at Tussing Rd. Expect del...</td>
#       <td>Brice Rd</td>
#       <td>Reynoldsburg</td>
#       <td>OH</td>
#       <td>43068-3402</td>
#       <td>US</td>
#       <td>US/Eastern</td>
#       <td>2016-02-08 05:51:00</td>
#       <td>37.9</td>
#       <td>0.0</td>
#       <td>100.0</td>
#       <td>29.65</td>
#       <td>10.0</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>Light Rain</td>
#       <td>Clear</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>201.0</td>
#       <td>39.063148</td>
#       <td>-84.032608</td>
#       <td>0.01</td>
#       <td>2016-02-08 06:49:27</td>
#       <td>2016-02-08 07:19:27</td>
#       <td>Accident on OH-32 State Route 32 Westbound at ...</td>
#       <td>State Route 32</td>
#       <td>Williamsburg</td>
#       <td>OH</td>
#       <td>45176</td>
#       <td>US</td>
#       <td>US/Eastern</td>
#       <td>2016-02-08 06:56:00</td>
#       <td>36.0</td>
#       <td>33.3</td>
#       <td>100.0</td>
#       <td>29.67</td>
#       <td>10.0</td>
#       <td>3.5</td>
#       <td>0.00</td>
#       <td>Overcast</td>
#       <td>Cloudy</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>201.0</td>
#       <td>39.747753</td>
#       <td>-84.205582</td>
#       <td>0.01</td>
#       <td>2016-02-08 07:23:34</td>
#       <td>2016-02-08 07:53:34</td>
#       <td>Accident on I-75 Southbound at Exits 52 52B US...</td>
#       <td>I-75 S</td>
#       <td>Dayton</td>
#       <td>OH</td>
#       <td>45417</td>
#       <td>US</td>
#       <td>US/Eastern</td>
#       <td>2016-02-08 07:38:00</td>
#       <td>35.1</td>
#       <td>31.0</td>
#       <td>96.0</td>
#       <td>29.64</td>
#       <td>9.0</td>
#       <td>4.6</td>
#       <td>0.00</td>
#       <td>Mostly Cloudy</td>
#       <td>Cloudy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>201.0</td>
#       <td>39.627781</td>
#       <td>-84.188354</td>
#       <td>0.01</td>
#       <td>2016-02-08 07:39:07</td>
#       <td>2016-02-08 08:09:07</td>
#       <td>Accident on McEwen Rd at OH-725 Miamisburg Cen...</td>
#       <td>Miamisburg Centerville Rd</td>
#       <td>Dayton</td>
#       <td>OH</td>
#       <td>45459</td>
#       <td>US</td>
#       <td>US/Eastern</td>
#       <td>2016-02-08 07:53:00</td>
#       <td>36.0</td>
#       <td>33.3</td>
#       <td>89.0</td>
#       <td>29.65</td>
#       <td>6.0</td>
#       <td>3.5</td>
#       <td>0.00</td>
#       <td>Mostly Cloudy</td>
#       <td>Cloudy</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(df_pd_lat["Temperature(F)"].isnull().sum())
print(df_pd_lat["Visibility(mi)"].isnull().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# 0
# </div>

# %%
# Keep only weather related columns for ML.
df_for_panda = df_weather_catg.select("Severity"  \
                          ,"Temperature(F)", "Visibility(mi)" \
                          , "Wind_Speed(mph)", "Weather_Category", "Pressure(in)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_for_panda)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Severity</th><th>Temperature(F)</th><th>Visibility(mi)</th><th>Wind_Speed(mph)</th><th>Weather_Category</th><th>Pressure(in)</th></tr></thead><tbody><tr><td>3</td><td>36.9</td><td>10.0</td><td>null</td><td>Clear</td><td>29.68</td></tr><tr><td>2</td><td>37.9</td><td>10.0</td><td>null</td><td>Clear</td><td>29.65</td></tr><tr><td>2</td><td>36.0</td><td>10.0</td><td>3.5</td><td>Cloudy</td><td>29.67</td></tr><tr><td>3</td><td>35.1</td><td>9.0</td><td>4.6</td><td>Cloudy</td><td>29.64</td></tr><tr><td>2</td><td>36.0</td><td>6.0</td><td>3.5</td><td>Cloudy</td><td>29.65</td></tr><tr><td>3</td><td>37.9</td><td>7.0</td><td>3.5</td><td>Clear</td><td>29.63
td></tr><tr><td>2</td><td>84.9</td><td>10.0</td><td>15.0</td><td>Cloudy</td><td>30.17</td></tr><tr><td>2</td><td>86.0</td><td>10.0</td><td>11.5</td><td>Cloudy</td><td>30.16</td></tr><tr><td>2</td><td>84.9</td><td>10.0</td><td>15.0</td><td>Cloudy</td><td>30.17</td></tr><tr><td>2</td><td>86.0</td><td>10.0</td><td>13.8</td><td>Cloudy</td><td>30.17</td></tr><tr><td>2</td><td>88.0</td><td>10.0</td><td>13.8</t ...

# %%
# Convert spark dataframe to pandas
df_panda = df_for_panda.toPandas()
df_panda.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Severity</th>
#       <th>Temperature(F)</th>
#       <th>Visibility(mi)</th>
#       <th>Wind_Speed(mph)</th>
#       <th>Weather_Category</th>
#       <th>Pressure(in)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>36.9</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>Clear</td>
#       <td>29.68</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>37.9</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>Clear</td>
#       <td>29.65</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>36.0</td>
#       <td>10.0</td>
#       <td>3.5</td>
#       <td>Cloudy</td>
#       <td>29.67</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>35.1</td>
#       <td>9.0</td>
#       <td>4.6</td>
#       <td>Cloudy</td>
#       <td>29.64</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>36.0</td>
#       <td>6.0</td>
#       <td>3.5</td>
#       <td>Cloudy</td>
#       <td>29.65</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_panda.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: Severity            2243108
# Temperature(F)      2180865
# Visibility(mi)      2171776
# Wind_Speed(mph)     1800314
# Weather_Category    2243108
# Pressure(in)        2185847
# dtype: int64</div>

# %%
print(df_panda["Temperature(F)"].isnull().sum())
print(df_panda["Visibility(mi)"].isnull().sum())
print(df_panda["Wind_Speed(mph)"].isnull().sum())
print(df_panda["Weather_Category"].isnull().sum())
print(df_panda["Pressure(in)"].isnull().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">62243
# 71332
# 442794
# 0
# 57261
# </div>

# %%
df_panda.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Severity</th>
#       <th>Temperature(F)</th>
#       <th>Visibility(mi)</th>
#       <th>Wind_Speed(mph)</th>
#       <th>Pressure(in)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>2.243108e+06</td>
#       <td>2.180865e+06</td>
#       <td>2.171776e+06</td>
#       <td>1.800314e+06</td>
#       <td>2.185847e+06</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2.383212e+00</td>
#       <td>6.123114e+01</td>
#       <td>9.124027e+00</td>
#       <td>8.844072e+00</td>
#       <td>3.003747e+01</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>5.482327e-01</td>
#       <td>1.914641e+01</td>
#       <td>2.986514e+00</td>
#       <td>4.973374e+00</td>
#       <td>2.267387e-01</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2.000000e+00</td>
#       <td>-7.780000e+01</td>
#       <td>0.000000e+00</td>
#       <td>1.200000e+00</td>
#       <td>0.000000e+00</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.000000e+00</td>
#       <td>4.890000e+01</td>
#       <td>1.000000e+01</td>
#       <td>5.800000e+00</td>
#       <td>2.992000e+01</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2.000000e+00</td>
#       <td>6.300000e+01</td>
#       <td>1.000000e+01</td>
#       <td>8.100000e+00</td>
#       <td>3.003000e+01</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>3.000000e+00</td>
#       <td>7.590000e+01</td>
#       <td>1.000000e+01</td>
#       <td>1.150000e+01</td>
#       <td>3.015000e+01</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>4.000000e+00</td>
#       <td>1.706000e+02</td>
#       <td>1.400000e+02</td>
#       <td>8.228000e+02</td>
#       <td>3.304000e+01</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import matplotlib.pyplot as plt
fig = df_panda["Temperature(F)"].plot(kind="hist", bins=50)
display(fig)

# %%
#Drop the rows whose every columns contain null
df_panda.dropna(how='all',inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fill null with zero values
df_panda_clean = df_panda.fillna(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(df_panda_clean["Temperature(F)"].isnull().sum())
print(df_panda_clean["Visibility(mi)"].isnull().sum())
print(df_panda_clean["Wind_Speed(mph)"].isnull().sum())
print(df_panda_clean["Weather_Category"].isnull().sum())
print(df_panda_clean["Pressure(in)"].isnull().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# 0
# 0
# 0
# 0
# </div>

# %%
df_panda_clean.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: Severity              int32
# Temperature(F)      float64
# Visibility(mi)      float64
# Wind_Speed(mph)     float64
# Weather_Category     object
# Pressure(in)        float64
# dtype: object</div>

# %%
df_panda_clean.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Severity</th>
#       <th>Temperature(F)</th>
#       <th>Visibility(mi)</th>
#       <th>Wind_Speed(mph)</th>
#       <th>Weather_Category</th>
#       <th>Pressure(in)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>36.9</td>
#       <td>10.0</td>
#       <td>0.0</td>
#       <td>Clear</td>
#       <td>29.68</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>37.9</td>
#       <td>10.0</td>
#       <td>0.0</td>
#       <td>Clear</td>
#       <td>29.65</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>36.0</td>
#       <td>10.0</td>
#       <td>3.5</td>
#       <td>Cloudy</td>
#       <td>29.67</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>35.1</td>
#       <td>9.0</td>
#       <td>4.6</td>
#       <td>Cloudy</td>
#       <td>29.64</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>36.0</td>
#       <td>6.0</td>
#       <td>3.5</td>
#       <td>Cloudy</td>
#       <td>29.65</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_source = spark.createDataFrame(df_panda_clean)
df_source.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: Row(Severity=3, Temperature(F)=36.9, Visibility(mi)=10.0, Wind_Speed(mph)=0.0, Weather_Category=&#39;Clear&#39;, Pressure(in)=29.68)</div>

# %%
# data_for_model.csv is final csv ready for machine learning model.
df_source.repartition(1).write.format("com.databricks.spark.csv").mode("overwrite").option("header", "true").save("dbfs:/FileStore/df/data_for_model.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X = df_panda_clean[["Temperature(F)", "Visibility(mi)", "Wind_Speed(mph)", "Weather_Category"]]
# X = df_panda_clean[["Temperature(F)", "Visibility(mi)", "Wind_Speed(mph)", "Weather_Category", "Pressure(in)"]]
# y = df_noweather_cond["Severity"].values.reshape(-1, 1)
y = df_panda_clean["Severity"]
print(X.shape, y.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(2243108, 4) (2243108,)
# </div>

# %%
data = X.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class PandasDummies(BaseEstimator, TransformerMixin):
    def transform(self, X, *_):
        return pd.get_dummies(X)
    
    def fit(self, *_):
        return self
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify =y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model1 = make_pipeline(PandasDummies(), StandardScaler(), RandomForestClassifier())
paramgrid = {"randomforestclassifier__n_estimators": [10, 30, 50],
             "randomforestclassifier__max_depth":[1, 5, 10] }
clf_grid_model1 = GridSearchCV(model1, paramgrid)
clf_grid_model1.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for &#39;cv&#39; instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by

# %%
print(f"Training Accuracy with Random Forest Classifier with grid search: {clf_grid_model1.score(X_train, y_train)}")
print(f"Testing Accuracy with Random Forest Classifier with grid search: {clf_grid_model1.score(X_test, y_test)}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# Training Accuracy with Random Forest Classifier with grid search: 0.6498792449286139
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# Testing Accuracy with Random Forest Classifier with grid search: 0.649628996909645
# </div>

# %%
clf_grid_model1.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = model1.steps[-1][1]
rf.feature_importances_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # Using best hyperparameters
# model = make_pipeline(PandasDummies(), StandardScaler(), RandomForestClassifier(n_estimators=10, max_depth=10))
# model.fit(X_train, y_train)
# print(f"Training Data Score without Random Forest Classifier: {model.score(X_train, y_train)}")
# print(f"Testing Data Score without Random Forest Classifier: {model.score(X_test, y_test)}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lg_model = make_pipeline(PandasDummies(), StandardScaler(), LogisticRegression())
paramgrid = {'logisticregression__C': [ 0.1, 1],
#              'logisticregression__max_iter': [110,120,130,140],
             'logisticregression__solver': ['saga'],
             'logisticregression__penalty': ['l1']
            }
lg_grid_model1 = GridSearchCV(lg_model, paramgrid)
lg_grid_model1.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for &#39;cv&#39; instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   &#34;the coef_ did not converge&#34;, ConvergenceWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   &#34;the coef_ did not converge&#34;, ConvergenceWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   &#34;the coef_ did not converge&#34;, ConvergenceWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   &#34;the coef_ did not converge&#34;, ConvergenceWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# /databricks/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /databricks/python/lib/python3.7/site-packages/sklearn/base.py:467: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /databricks/python/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to &#39;auto&#39; in 0.22. Specify the multi_class option to silence this warning.
#   &#34;this warning.&#34;, FutureWarning)
# /databricks/python/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning:

# %%
print(f"Training Data Score with Logistic Classifier with grid search: {lg_grid_model1.score(X_train, y_train)}")
print(f"Testing Data Score with Logistic Classifier with grid search: {lg_grid_model1.score(X_test, y_test)}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NotFittedError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3730257924741028&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#34;Training Data Score with Logistic Classifier with grid search: {lg_grid_model1.score(X_train, y_train)}&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#34;Testing Data Score with Logistic Classifier with grid search: {lg_grid_model1.score(X_test, y_test)}&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/sklearn/model_selection/_search.py</span> in <span class="ansi-cyan-fg">score</span><span class="ansi-blue-fg">(self, X, y)</span>
# <span class="ansi-green-intense-fg ansi-bold">    454</span>         score <span class="ansi-blue-fg">:</span> float
# <span class="ansi-green-intense-fg ansi-bold">    455</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 456</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_check_is_fitted<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;score&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    457</span>         <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>scorer_ <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    458</span>             raise ValueError(&#34;No score function explicitly defined, &#34;
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/sklearn/model_selection/_search.py</span> in <span class="ansi-cyan-fg">_check_is_fitted</span><span class="ansi-blue-fg">(self, method_name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    472</span>                                  % (type(self).__name__, method_name))
# <span class="ansi-green-intense-fg ansi-bold">    473</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 474</span><span class="ansi-red-fg">             </span>check_is_fitted<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;best_estimator_&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    475</span>
# <span class="ansi-green-intense-fg ansi-bold">    476</span>     <span class="ansi-blue-fg">@</span>if_delegate_has_method<span class="ansi-blue-fg">(</span>delegate<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;best_estimator_&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;estimator&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/sklearn/utils/validation.py</span> in <span class="ansi-cyan-fg">check_is_fitted</span><span class="ansi-blue-fg">(estimator, attributes, msg, all_or_any)</span>
# <span class="ansi-green-intense-fg ansi-bold">    949</span>
# <span class="ansi-green-intense-fg ansi-bold">    950</span>     <span class="ansi-green-fg">if</span> <span class="ansi-green-fg">not</span> all_or_any<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span>hasattr<span class="ansi-blue-fg">(</span>estimator<span class="ansi-blue-fg">,</span> attr<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> attr <span class="ansi-green-fg">in</span> attributes<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 951</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> NotFittedError<span class="ansi-blue-fg">(</span>msg <span class="ansi-blue-fg">%</span> <span class="ansi-blue-fg">{</span><span class="ansi-blue-fg">&#39;name&#39;</span><span class="ansi-blue-fg">:</span> type<span class="ansi-blue-fg">(</span>estimator<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>__name__<span class="ansi-blue-fg">}</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    952</span>
# <span class="ansi-green-intense-fg ansi-bold">    953</span>
#
# <span class="ansi-red-fg">NotFittedError</span>: This GridSearchCV instance is not fitted yet. Call &#39;fit&#39; with appropriate arguments before using this method.</div>
